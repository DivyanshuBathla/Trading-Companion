# %% [markdown]
# //Merging the ticker and company name with their respective sector details

# %%
import pandas as pd
import numpy as np

# %%
ticker=pd.read_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker.csv')

# %%
sector=pd.read_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\sector_wise.csv')

# %%
ticker.head()
# Out:
#        SYMBOL                           NAME OF COMPANY  SERIES  \
# 0   20MICRONS                        20 Microns Limited      EQ
# 1  21STCENMGM  21st Century Management Services Limited      EQ
# 2   3IINFOLTD                       3i Infotech Limited      EQ
# 3     3MINDIA                          3M India Limited      EQ
# 4      3PLAND                  3P Land Holdings Limited      EQ
#
#    DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0        06-Oct-08               5            1  INE144J01027            5
# 1        03-May-95              10            1  INE253B01015           10
# 2        22-Oct-21              10            1  INE748C01038           10
# 3        13-Aug-04              10            1  INE470A01017           10
# 4        19-Jul-95               2            1  INE105C01023            2

# %%
sector.head()
# Out:
#        Symbol Links     Close  Change(%)      Last Updated At      Open  \
# 0   20MICRONS           38.40      -3.27  24/05/2017 15:29:56     39.20
# 1  3IINFOTECH            4.50      -5.26  24/05/2017 15:29:54      4.75
# 2     3MINDIA        12801.00      -3.71  24/05/2017 15:29:48  13140.10
# 3     63MOONS           68.05      -1.87  24/05/2017 15:29:41     70.00
# 4     8KMILES          564.90       1.17  24/05/2017 15:29:58    559.95
#
#        High      Low     Volume Volume Score  Market Cap       Sector  \
# 0     39.95     38.0    57583.0      -0.13 X       56.31       Mining
# 1      4.80      4.5  3490003.0       1.36 X       86.66    Computers
# 2  13264.20  12801.0     3239.0       0.68 X    14428.35  Diversified
# 3     71.40     67.6    75435.0       1.69 X        0.00          NaN
# 4    585.00    555.1    58857.0       0.25 X        0.00    Computers
#
#              Sub Sector
# 0       Mining/Minerals
# 1  Computers - Software
# 2           Diversified
# ...

# %%
merge=pd.DataFrame()

# %%
(ticker.shape)[0]
# Out:
# 1828

# %%
ticker_arr=np.array(ticker)
sector_arr=np.array(sector)

# %%
ticker_arr[0]
# Out:
# array(['20MICRONS', '20 Microns Limited', 'EQ', '06-Oct-08', 5, 1,
#        'INE144J01027', 5], dtype=object)

# %%
ticker_arr[0][0]
# Out:
# '20MICRONS'

# %%
ticker.head()
# Out:
#        SYMBOL                           NAME OF COMPANY  SERIES  \
# 0   20MICRONS                        20 Microns Limited      EQ
# 1  21STCENMGM  21st Century Management Services Limited      EQ
# 2   3IINFOLTD                       3i Infotech Limited      EQ
# 3     3MINDIA                          3M India Limited      EQ
# 4      3PLAND                  3P Land Holdings Limited      EQ
#
#    DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0        06-Oct-08               5            1  INE144J01027            5
# 1        03-May-95              10            1  INE253B01015           10
# 2        22-Oct-21              10            1  INE748C01038           10
# 3        13-Aug-04              10            1  INE470A01017           10
# 4        19-Jul-95               2            1  INE105C01023            2

# %%
sector.head()
# Out:
#        Symbol Links     Close  Change(%)      Last Updated At      Open  \
# 0   20MICRONS           38.40      -3.27  24/05/2017 15:29:56     39.20
# 1  3IINFOTECH            4.50      -5.26  24/05/2017 15:29:54      4.75
# 2     3MINDIA        12801.00      -3.71  24/05/2017 15:29:48  13140.10
# 3     63MOONS           68.05      -1.87  24/05/2017 15:29:41     70.00
# 4     8KMILES          564.90       1.17  24/05/2017 15:29:58    559.95
#
#        High      Low     Volume Volume Score  Market Cap       Sector  \
# 0     39.95     38.0    57583.0      -0.13 X       56.31       Mining
# 1      4.80      4.5  3490003.0       1.36 X       86.66    Computers
# 2  13264.20  12801.0     3239.0       0.68 X    14428.35  Diversified
# 3     71.40     67.6    75435.0       1.69 X        0.00          NaN
# 4    585.00    555.1    58857.0       0.25 X        0.00    Computers
#
#              Sub Sector
# 0       Mining/Minerals
# 1  Computers - Software
# 2           Diversified
# ...

# %%
unknown=pd.DataFrame()

# %%
sector_arr[0][12]
# Out:
# 'Mining/Minerals'

# %%
k=0
flag=0
for i in range ((sector_arr.shape)[0]):
    flag=0
    for j in range((ticker_arr.shape)[0]):
        if sector_arr[i][0]==ticker_arr[j][0]:
            data={"Ticker":ticker_arr[j][0],"company_name":ticker_arr[j][1],"sector":sector_arr[i][11],"sub sector":sector_arr[i][12],"series":ticker_arr[j][2],"date of listing":ticker_arr[j][3],
            "paid up value":ticker_arr[j][4],"market lot":ticker_arr[j][5],"isin number":ticker_arr[j][6],"face value":ticker_arr[j][7],}
            temp_df=pd.DataFrame(data,index=[k])
            k=k+1
            merge=merge.append(temp_df)
            flag=1
    if flag==0:
        data={"unknown":sector_arr[i][0]}
        temp_df=pd.DataFrame(data,index=[i])
        unknown=unknown.append(temp_df)
# Out:
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\166029123.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\166029123.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unknown=unknown.append(temp_df)
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\166029123.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\166029123.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# ...

# %%
merge.shape
# Out:
# (1148, 10)

# %%
merge.to_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker_sector_merge1.csv')

# %%
# unknown.to_csv('unknown.csv')

# %% [markdown]
# //merging industry name form test.csv with ticker.csv as some industry name is missing in sector_wise.csv

# %%
ticker=pd.read_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker.csv')

# %%
sector=pd.read_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\Industry_names.csv')

# %%
sector.dropna()
# Out:
#          company name                            inustry  last price change  \
# 1        21st Cen Mgt                  Finance - General       22.85  -0.45
# 2         3i Infotech               Computers - Software       43.35   -0.5
# 3            3M India                        Diversified    24295.30   -311
# 6       5paisa Capita                      Miscellaneous      335.20  -2.95
# 7       63 Moons Tech               Computers - Software      163.35    2.3
# ...               ...                                ...         ...    ...
# 1726    Zodiac Energy  Power - Generation & Distribution      149.80   3.25
# 1727  Zota Health Car                    Pharmaceuticals      280.65  -5.35
# 1728  Zuari Agro Chem                        Fertilisers      170.05   -5.1
# 1729       Zuari Ind.                        Fertilisers      162.10   -2.7
# 1731   Zydus Wellness                   Vanaspati & Oils     1657.00   33.2
#
#       %cng mkt cap
# 1    -1.93      24
# ...

# %%
ticker_arr=np.array(ticker)
sector_arr=np.array(sector)

# %%
ticker.head()
# Out:
#        SYMBOL                           NAME OF COMPANY  SERIES  \
# 0   20MICRONS                        20 Microns Limited      EQ
# 1  21STCENMGM  21st Century Management Services Limited      EQ
# 2   3IINFOLTD                       3i Infotech Limited      EQ
# 3     3MINDIA                          3M India Limited      EQ
# 4      3PLAND                  3P Land Holdings Limited      EQ
#
#    DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0        06-Oct-08               5            1  INE144J01027            5
# 1        03-May-95              10            1  INE253B01015           10
# 2        22-Oct-21              10            1  INE748C01038           10
# 3        13-Aug-04              10            1  INE470A01017           10
# 4        19-Jul-95               2            1  INE105C01023            2

# %%
sector.head()
# Out:
#    company name               inustry  last price change  %cng mkt cap
# 0           NaN                   NaN         NaN    NaN   NaN     NaN
# 1  21st Cen Mgt     Finance - General       22.85  -0.45 -1.93      24
# 2   3i Infotech  Computers - Software       43.35   -0.5 -1.14     730
# 3      3M India           Diversified    24295.30   -311 -1.26  27,369
# 4           NaN                   NaN         NaN    NaN   NaN     NaN

# %%
ticker.shape
# Out:
# (1828, 8)

# %%
sector.shape
# Out:
# (1732, 6)

# %%
merge=pd.DataFrame()

# %%
k=0
flag=0
for i in range ((sector_arr.shape)[0]):
    flag=0
    for j in range((ticker_arr.shape)[0]):
        try:
       
        
            ans=set(sector_arr[i][0].split()).intersection(ticker_arr[j][1].split())
            if len(ans)>0: 
                data={"Ticker":ticker_arr[j][0],"company_name":ticker_arr[j][1],"sector":sector_arr[i][1],"series":ticker_arr[j][2],"date of listing":ticker_arr[j][3],
                "paid up value":ticker_arr[j][4],"market lot":ticker_arr[j][5],"isin number":ticker_arr[j][6],"face value":ticker_arr[j][7]}
                temp_df=pd.DataFrame(data,index=[k])
                k=k+1
                merge=merge.append(temp_df)
                flag=1
                break
                
        except:
             break
# Out:
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\1162440122.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\1162440122.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\1162440122.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# C:\Users\as\AppData\Local\Temp\ipykernel_11484\1162440122.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merge=merge.append(temp_df)
# ...

# %%
merge.shape
# Out:
# (1593, 9)

# %%
merge.to_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker_sector_merge_2.csv')

# %%
ans=set(sector_arr[1][0].split()).intersection(ticker_arr[1][1].split())

# %%
merge.shape
# Out:
# (1593, 9)

# %%
merge.head()
# Out:
#        Ticker                              company_name  \
# 0  21STCENMGM  21st Century Management Services Limited
# 1   3IINFOLTD                       3i Infotech Limited
# 2     3MINDIA                          3M India Limited
# 3     63MOONS             63 moons technologies limited
# 4    A2ZINFRA             A2Z Infra Engineering Limited
#
#                              sector series date of listing  paid up value  \
# 0                 Finance - General     EQ       03-May-95             10
# 1              Computers - Software     EQ       22-Oct-21             10
# 2                       Diversified     EQ       13-Aug-04             10
# 3              Computers - Software     EQ       20-Jun-05              2
# 4  Power - Transmission & Equipment     EQ       23-Dec-10             10
#
#    market lot   isin number  face value
# 0           1  INE253B01015          10
# 1           1  INE748C01038          10
# 2           1  INE470A01017          10
# ...

# %%
merge.to_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker_sector_merge_2.csv')

# %%
ticker=pd.read_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker_sector_merge_1.csv')
sector=pd.read_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker_sector_merge_2.csv')

# %%
ticker_arr=np.array(ticker)
sector_arr=np.array(sector)

# %%
ticker_arr[2]
# Out:
# array([2, '63MOONS', '63 moons technologies limited', nan, nan, 'EQ',
#        '20-Jun-05', 2, 1, 'INE111B01023', 2], dtype=object)

# %%
k=0
flag=0
for i in range ((ticker.shape)[0]):
    if type(ticker_arr[i][3]==float):

        for j in range((sector_arr.shape)[0]):
            if ticker_arr[i][1]==sector_arr[j][1]:
                ticker_arr[i][3]=sector_arr[j][3]

# %%
ticker_arr=pd.DataFrame(ticker_arr)

# %%
ticker_arr.head()
# Out:
#   0           1                              2                         3   \
# 0  0   20MICRONS             20 Microns Limited             Miscellaneous
# 1  1     3MINDIA               3M India Limited                 Packaging
# 2  2     63MOONS  63 moons technologies limited      Computers - Software
# 3  3    A2ZINFRA  A2Z Infra Engineering Limited  Infrastructure - General
# 4  4  AARTIDRUGS            Aarti Drugs Limited                 Chemicals
#
#                       4   5          6   7  8             9   10
# 0        Mining/Minerals  EQ  06-Oct-08   5  1  INE144J01027   5
# 1            Diversified  EQ  13-Aug-04  10  1  INE470A01017  10
# 2                    NaN  EQ  20-Jun-05   2  1  INE111B01023   2
# 3  Engineering - General  EQ  23-Dec-10  10  1  INE619I01012  10
# 4        Pharmaceuticals  EQ  19-Sep-03  10  1  INE767A01016  10

# %%
ticker_arr=np.array(ticker_arr)

# %%
k=0
flag=0
for i in range ((ticker.shape)[0]):
    if type(ticker_arr[i][4]==float):
        ticker_arr[i][4]=ticker_arr[i][3]

# %%
ticker_arr=pd.DataFrame(ticker_arr)

# %%
ticker_arr.to_csv('C:\\Users\\as\\Desktop\\major_project\\Hybrid Model\\Data files\\ticker_sector_merge.csv')
